# %%
test = "a test string"
for i in range(10000348690000):        # it takes forever, so choose this value wisely!
    
    if len(test) < 200000000:      # somewhere above this limit I get errors
        test += test
    else:
        test = test[0:len(test)//2] # if the string gets too long just cut it.
